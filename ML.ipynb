# %%
# !pip install numpy
def at(a, b):
  return a+b 
print(at(2,4))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-1.23.0-cp310-cp310-win_amd64.whl (14.6 MB)
#      ---------------------------------------- 14.6/14.6 MB 9.6 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-1.23.0
# 6
#   WARNING: The script f2py.exe is installed in 'C:\Users\Chocobo\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
import matplotlib as matplotlib
from __future__ import division, print_function, unicode_literals
import numpy as np 
import matplotlib.pyplot as plt
# height (cm)
X = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
# dick (cm)
y = np.array([[ 10, 11, 12,  14, 16, 18, 20, 22, 23, 24,25, 26, 28]]).T
# Visualize data 
plt.plot(X, y, 'ro')
plt.axis([140, 190, 45, 75])
plt.xlabel('Height (cm)')
plt.ylabel('Length (cm)')
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\chocobo\appdata\roaming\python\python310\site-packages (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (1.23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: six>=1.5 in c:\users\chocobo\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Mục mới

# %%
one = np.ones((X.shape[0], 1))
Xbar = np.concatenate((one, X), axis = 1)

# Calculating weights of the fitting line 
A = np.dot(Xbar.T, Xbar)
b = np.dot(Xbar.T, y)
w = np.dot(np.linalg.pinv(A), b)
print('w = ', w)
# Preparing the fitting line 
w_0 = w[0][0]
w_1 = w[1][0]
x0 = np.linspace(145, 185, 2)
y0 = w_0 + w_1*x0

# Drawing the fitting line 
plt.plot(X.T, y.T, 'ro')     # data 
plt.plot(x0, y0)               # the fitting line
plt.axis([140, 190, 45, 75])
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()
# Out:
# w =  [[-67.1578799 ]
#  [  0.51874824]]

# %%
y1 = w_1*165 + w_0
y2 = w_1*300 + w_0

print( u'Predict dick length of person with height 190 cm: %.2f (cm), '  %(y1) )
print( u'Predict dick length of person with height 300 cm: %.2f (cm), '  %(y2) )
# Out:
# Predict dick length of person with height 190 cm: 18.44 (cm), real number: 52 (cm)
# Predict dick length of person with height 300 cm: 88.47 (cm), real number: 56 (cm)
